# %%
import pandas as pd

df = pd.read_csv('./EasyVisa.csv')
print(df.shape)
# Out:
# (25480, 12)

# %%
df = df.to_dict(orient = 'records')

# %%
len(df)
# Out:
# 25480

# %%
from pymongo import MongoClient
import os

client = MongoClient(os.getenv('MONGO_URI'))
db = client['CheckMyVisaDB']
collection = db['VisaData']

result = collection.insert_many(df)

# %%
df = pd.DataFrame(collection.find({}))
df.head()
# Out:
#                         _id case_id continent education_of_employee  \
# 0  6934496942367016e3eebcbc  EZYV01      Asia           High School
# 1  6934496942367016e3eebcbd  EZYV02      Asia              Master's
# 2  6934496942367016e3eebcbe  EZYV03      Asia            Bachelor's
# 3  6934496942367016e3eebcbf  EZYV04      Asia            Bachelor's
# 4  6934496942367016e3eebcc0  EZYV05    Africa              Master's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  N                     N            14513         2007
# 1                  Y                     N             2412         2002
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                 West         592.2029         Hour                  Y
# 1            Northeast       83425.6500         Year                  Y
# 2                 West      122996.8600         Year                  Y
# 3                 West       83434.0300         Year                  Y
# 4                South      149907.3900         Year                  Y
#
#   case_status
# 0      Denied
# 1   Certified
# 2      Denied
# 3      Denied
# 4   Certified
